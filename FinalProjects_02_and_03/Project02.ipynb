# %% [markdown]
# # **Name : Maheru Tabassum Ohana, ID : 2125051015**

# %% [markdown]
# # **Import Libraries**

# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/DM_FINAL_LAB_PROJECT/heart_disease.csv')
df
# Out:
#         age  sex  cp trestbps    chol  fbs  restecg thalach  exang oldpeak  \
# 0      high    1   3     high  medium    1        0  medium      0    high
# 1       low    1   2   medium  medium    0        1    high      0    high
# 2       low    0   1   medium     low    0        0    high      0    high
# 3    medium    1   1      low  medium    0        1    high      0  medium
# 4    medium    0   0      low    high    0        1    high      1  medium
# ..      ...  ...  ..      ...     ...  ...      ...     ...    ...     ...
# 298  medium    0   0     high  medium    0        1     low      1  medium
# 299     low    1   3      low    high    0        1     low      0  medium
# 300    high    1   0     high     low    1        1     low      0    high
# 301  medium    1   0   medium     low    0        1     low      1  medium
# 302  medium    0   1   medium  medium    0        0    high      0     low
#
#      slope  ca  thal  target
# 0        0   0     1       1
# ...

# %% [markdown]
# # **Objective 1: Preprocess the mushroom dataset**

# %%
# Step 1: Import libraries
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Step 2: Load dataset (replace with your path if needed)
df = pd.read_csv('/content/drive/MyDrive/DM_FINAL_LAB_PROJECT/heart_disease.csv')

# Step 3: Convert each row into a list of feature=value
transactions = []
for _, row in df.iterrows():
    transactions.append([f"{col}_{row[col]}" for col in df.columns])

# %% [markdown]
# # **Objective 2: Use Apriori with support = 0.3**

# %%
# Step 4: One-hot encoding
te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_array, columns=te.columns_)

# Step 5: Apply Apriori
frequent_itemsets = apriori(df_encoded, min_support=0.3, use_colnames=True)
frequent_itemsets.sort_values(by='support', ascending=False, inplace=True)

# %% [markdown]
# # **Objective 3: Generate Top 10 Rules with confidence = 0.7**

# %%
# Step 6: Generate rules
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.7)

# Step 7: Sort and select top 10 rules by confidence and lift
top_10_rules = rules.sort_values(by=['confidence', 'lift'], ascending=False).head(10)

# Step 8: Display rules
print(top_10_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
#                  antecedents consequents   support  confidence      lift
# 79            (trestbps_low)     (fbs_0)  0.313531    0.940594  1.104651
# 44            (ca_0, thal_2)     (fbs_0)  0.343234    0.912281  1.071399
# 87  (target_1, ca_0, thal_2)     (fbs_0)  0.303630    0.901961  1.059280
# 53            (ca_0, thal_2)  (target_1)  0.336634    0.894737  1.643062
# 24           (ca_0, exang_0)     (fbs_0)  0.386139    0.893130  1.048908
# 97         (thal_2, slope_2)   (exang_0)  0.300330    0.892157  1.325115
# 2                     (ca_0)     (fbs_0)  0.511551    0.885714  1.040199
# 88     (fbs_0, thal_2, ca_0)  (target_1)  0.303630    0.884615  1.624476
# 28          (target_1, ca_0)     (fbs_0)  0.379538    0.884615  1.038909
# 3                   (thal_2)     (fbs_0)  0.481848    0.879518  1.032922

# %%
import pandas as pd

df_encoded = pd.get_dummies(df, columns=df.columns)
df_encoded
# Out:
#      age_high  age_low  age_medium  sex_0  sex_1   cp_0   cp_1   cp_2   cp_3  \
# 0        True    False       False  False   True  False  False  False   True
# 1       False     True       False  False   True  False  False   True  False
# 2       False     True       False   True  False  False   True  False  False
# 3       False    False        True  False   True  False   True  False  False
# 4       False    False        True   True  False   True  False  False  False
# ..        ...      ...         ...    ...    ...    ...    ...    ...    ...
# 298     False    False        True   True  False   True  False  False  False
# 299     False     True       False  False   True  False  False  False   True
# 300      True    False       False  False   True   True  False  False  False
# 301     False    False        True  False   True   True  False  False  False
# 302     False    False        True   True  False  False   True  False  False
#
# ...

# %%
# Frequent itemset generation

frequent_itemsets = apriori(df_encoded, min_support=0.5, use_colnames=True)
print(frequent_itemsets)
# Out:
#     support          itemsets
# 0  0.683168           (sex_1)
# 1  0.851485           (fbs_0)
# 2  0.501650       (restecg_1)
# 3  0.673267         (exang_0)
# 4  0.577558            (ca_0)
# 5  0.547855          (thal_2)
# 6  0.544554        (target_1)
# 7  0.574257    (sex_1, fbs_0)
# 8  0.577558  (fbs_0, exang_0)
# 9  0.511551     (ca_0, fbs_0)

# %%
for index, row in frequent_itemsets.iterrows():
  print(row)
# Out:
# support     0.683168
# itemsets     (sex_1)
# Name: 0, dtype: object
# support     0.851485
# itemsets     (fbs_0)
# Name: 1, dtype: object
# support         0.50165
# itemsets    (restecg_1)
# Name: 2, dtype: object
# support      0.673267
# itemsets    (exang_0)
# Name: 3, dtype: object
# support     0.577558
# itemsets      (ca_0)
# Name: 4, dtype: object
# support     0.547855
# itemsets    (thal_2)
# Name: 5, dtype: object
# support       0.544554
# itemsets    (target_1)
# Name: 6, dtype: object
# support           0.574257
# itemsets    (sex_1, fbs_0)
# Name: 7, dtype: object
# support             0.577558
# itemsets    (fbs_0, exang_0)
# Name: 8, dtype: object
# support          0.511551
# itemsets    (ca_0, fbs_0)
# Name: 9, dtype: object

# %%
# Association rule generation
num_itemsets = len(frequent_itemsets)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7, num_itemsets = num_itemsets)
rules
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0     (sex_1)     (fbs_0)            0.683168            0.851485  0.574257
# 1   (exang_0)     (fbs_0)            0.673267            0.851485  0.577558
# 2      (ca_0)     (fbs_0)            0.577558            0.851485  0.511551
#
#    confidence      lift  representativity  leverage  conviction  \
# 0    0.840580  0.987192               1.0 -0.007450    0.931593
# 1    0.857843  1.007467               1.0  0.004281    1.044725
# 2    0.885714  1.040199               1.0  0.019769    1.299505
#
#    zhangs_metric   jaccard  certainty  kulczynski
# 0      -0.039337  0.597938  -0.073430    0.757499
# 1       0.022684  0.609756   0.042810    0.768069
# 2       0.091482  0.557554   0.230476    0.743245

# %%
rules = rules.sort_values(by=['confidence', 'lift', 'support'], ascending=False)
rules
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 2      (ca_0)     (fbs_0)            0.577558            0.851485  0.511551
# 1   (exang_0)     (fbs_0)            0.673267            0.851485  0.577558
# 0     (sex_1)     (fbs_0)            0.683168            0.851485  0.574257
#
#    confidence      lift  representativity  leverage  conviction  \
# 2    0.885714  1.040199               1.0  0.019769    1.299505
# 1    0.857843  1.007467               1.0  0.004281    1.044725
# 0    0.840580  0.987192               1.0 -0.007450    0.931593
#
#    zhangs_metric   jaccard  certainty  kulczynski
# 2       0.091482  0.557554   0.230476    0.743245
# 1       0.022684  0.609756   0.042810    0.768069
# 0      -0.039337  0.597938  -0.073430    0.757499

# %%
rules[:40][['antecedents', 'consequents']]
# Out:
#   antecedents consequents
# 2      (ca_0)     (fbs_0)
# 1   (exang_0)     (fbs_0)
# 0     (sex_1)     (fbs_0)

# %%
from mlxtend.frequent_patterns import fpgrowth

# Frequent itemset generation using FP-Growth
frequent_itemsets = fpgrowth(df_encoded, min_support=0.8, use_colnames=True)
print(frequent_itemsets)

# Association rule generation
num_itemsets = len(frequent_itemsets)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7, num_itemsets = num_itemsets)
rules = rules.sort_values(by=['confidence', 'lift', 'support'], ascending=False)
rules
# Out:
#     support itemsets
# 0  0.851485  (fbs_0)
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
